# %%
# Load YOLO 11 object detection model
from ultralytics import YOLO

import cv2
import math

# %%
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")


classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 88.2ms
# Speed: 1.6ms preprocess, 88.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 54.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.27
# Class name --> sofa
# Speed: 1.8ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 50.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.2ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.1ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.8ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.3ms preprocess, 46.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.3ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.8ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.1ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.1ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.8ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.3ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.9ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.2ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.7ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.3ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.8ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.9ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.9ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.7ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 54.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 54.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.2ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.8ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.1ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.9ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.0ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.0ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.3ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.6ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.1ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.7ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.9ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 45.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.1ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.9ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.1ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.8ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.4ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.8ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.3ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.9ms preprocess, 63.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.4ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.8ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.2ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.9ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.1ms preprocess, 42.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.9ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.2ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.8ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.4ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.1ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.3ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.8ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 0.8ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.0ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.2ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 0.9ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.0ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.1ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 41.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.9ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.1ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 42.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.27
# Class name --> remote
# Speed: 1.1ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 42.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.39
# Class name --> remote
# Speed: 0.9ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 43.4ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.31
# Class name --> remote
# Speed: 1.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.9ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.9ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.1ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.2ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.9ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 49.9ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.39
# Class name --> remote
# Speed: 1.1ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.9ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.3ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.9ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.8ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 42.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.32
# Class name --> remote
# Speed: 0.8ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.2ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.9ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 43.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.29
# Class name --> remote
# Speed: 1.3ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.1ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.3ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.4ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.9ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 63.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.1ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.3ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 0.9ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.0ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.8ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.9ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.3ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.8ms preprocess, 46.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.1ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.2ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.8ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.2ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.0ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 0.7ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.3ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 0.9ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.8ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.7ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.8ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.1ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 0.8ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.2ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.8ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.0ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.2ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.2ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.7ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.2ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.9ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.1ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.6ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 0.8ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.6ms
# Confidence ---> 0.59
# Class name --> person
# Speed: 0.8ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 0.9ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 65.6ms
# Confidence ---> 0.5
# Class name --> cat
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.1ms preprocess, 65.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 43.6ms
# Confidence ---> 0.62
# Class name --> cat
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.9ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 44.1ms
# Confidence ---> 0.59
# Class name --> cat
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.1ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.8ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.8ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 44.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.48
# Class name --> toothbrush
# Speed: 1.1ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 42.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 0.9ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.1ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.8ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.2ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.9ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.2ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 41.8ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Class name --> toothbrush
# Speed: 0.8ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.8ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.7ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 44.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> remote
# Speed: 1.2ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 44.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.43
# Class name --> remote
# Speed: 1.1ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 43.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.28
# Class name --> remote
# Speed: 1.1ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 43.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.38
# Class name --> remote
# Speed: 0.9ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 44.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.36
# Class name --> remote
# Speed: 1.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.8ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.2ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 47.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.36
# Class name --> remote
# Speed: 0.7ms preprocess, 47.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 44.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.1ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.7ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.2ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.9ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.9ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.1ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.2ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 48.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 43.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.4ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.8ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 41.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.34
# Class name --> remote
# Speed: 1.0ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 40.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.27
# Class name --> remote
# Speed: 1.3ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.3ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.8ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.9ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 44.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.6ms preprocess, 47.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 46.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.31
# Class name --> remote
# Speed: 0.7ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.0ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.1ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.8ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.2ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.7ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.85
# Class name --> person
# ...
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.1ms preprocess, 67.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.9ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.1ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 1.5ms preprocess, 55.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.0ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.8ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 9.9ms preprocess, 57.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.3ms preprocess, 44.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.2ms preprocess, 59.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.3ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.1ms preprocess, 57.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 46.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 46.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 45.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.4ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.1ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.7ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 45.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.1ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 48.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 14.6ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 52.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 0.8ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 46.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.0ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.1ms preprocess, 65.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 48.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.8ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.8ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 45.1ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.6ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.7ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.2ms preprocess, 58.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 50.3ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.9ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.8ms preprocess, 47.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.6ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 45.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.8ms preprocess, 45.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 52.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 10.3ms preprocess, 52.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.8ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.0ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 46.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.9ms preprocess, 46.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.4ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 0.8ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.2ms preprocess, 47.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.4ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.7ms preprocess, 61.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.3ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.8ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.2ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.9ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 70.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.8ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 46.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.9ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 45.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.3ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 6.9ms preprocess, 57.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 51.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.4ms preprocess, 51.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 48.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.2ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.2ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 67.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.1ms preprocess, 67.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 1.3ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 1.2ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.1ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 45.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.32
# Class name --> sofa
# Speed: 1.1ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.6ms preprocess, 63.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.9ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 1 cell phone, 42.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
# Confidence ---> 0.36
# Class name --> sofa
# Speed: 1.0ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.7ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.6ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.8ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.8ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.1ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.6ms preprocess, 57.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 45.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 64.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.2ms preprocess, 64.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 48.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.1ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.8ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.2ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.0ms preprocess, 43.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 6.2ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.0ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
